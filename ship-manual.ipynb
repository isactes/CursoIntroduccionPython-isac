# %%
pip install ipywidgets
# Out:
# ...
#      -------------------------------------- 123.4/123.4 KB 1.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 245.1/245.1 KB 3.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.6/1.6 MB 3.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 73.3/73.3 KB 1.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 72.9/72.9 KB 267.6 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 9.9/9.9 MB 3.3 MB/s eta 0:00:00
# ...
#      --------------------------------------- 61.6/61.6 KB 84.2 kB/s eta 0:00:00
# ...
#      -------------------------------------- 60.6/60.6 KB 535.4 kB/s eta 0:00:00
# ...
#      -------------------------------------- 561.6/561.6 KB 2.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 59.5/59.5 KB 1.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 133.1/133.1 KB 1.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 128.2/128.2 KB 1.9 MB/s eta 0:00:00
# ...
